# %%
""" Initialize the notebook """
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib as mpl
import numpy as np
import NoTrendNormalModel
import TrendNormalModel
import TrendPoissonModel
import TrendExponentialModel
import TrendGammaModel
import TrendGEVModel

#Set the default font for plots
font = { 'family' : 'sans-serif', \
         'size' : '15', \
         'weight' : 'bold'}
mpl.rc('font', **font)

# print any git repository info too
import git
try:
    _repo = git.Repo(search_parent_directories=True)
    _git_sha = _repo.head.object.hexsha
    _git_short_sha = _repo.git.rev_parse(_git_sha, short=7)
    _git_branch = _repo.active_branch
    print("On branch {} at rev {}".format(_git_branch,_git_short_sha))
except:
    print("No repository detected.")

import os, socket
print("{}:{}".format(socket.gethostname(),os.getcwd()))

# set the seed to 0 for repeatibility
np.random.seed(0)
# Out:
# On branch master at rev 18dfa00
# 9ce5b94dfcc8:/home/jovyan/ClimTrends

# %%
""" Test the normal model, no trends"""
NoTrendNormalModel.NoTrendNormalModel(test_only = True).run_model_test((0.0, 0.25))

# %%
TrendNormalModel.TrendNormalModel(test_only = True).run_model_test((0.01, 10.0, 0.25))

# %%
TrendPoissonModel.TrendPoissonModel(test_only = True).run_model_test((0.01, 10))

# %%
TrendExponentialModel.TrendExponentialModel(test_only = True).run_model_test((0.01, 10))
# Out:
# /home/jovyan/ClimTrends/TrendExponentialModel.py:37: RuntimeWarning: invalid value encountered in log_exponential_pdf_fast
#   return np.sum(log_exponential_pdf_fast(self.y, mu))

# %%
TrendGammaModel.TrendGammaModel(test_only = True).run_model_test((0.01, 10, 0.01, 3.0))
# Out:
# /home/jovyan/ClimTrends/TrendGammaModel.py:38: RuntimeWarning: invalid value encountered in log_gamma_pdf_fast
#   return np.sum(log_gamma_pdf_fast(self.y, alpha, beta))

# %%
TrendGEVModel.TrendGEVModel(test_only = True).run_model_test((-0.001, 10, 2, 0.5))
# Out:
# /home/jovyan/ClimTrends/TrendGEVModel.py:38: RuntimeWarning: invalid value encountered in log_gev_pdf_fast
#   return np.sum(log_gev_pdf_fast(self.y, mu, sigma, xi))
# /opt/conda/lib/python3.6/site-packages/emcee/ensemble.py:335: RuntimeWarning: invalid value encountered in subtract
#   lnpdiff = (self.dim - 1.) * np.log(zz) + newlnprob - lnprob0
# /opt/conda/lib/python3.6/site-packages/emcee/ensemble.py:336: RuntimeWarning: invalid value encountered in greater
#   accept = (lnpdiff > np.log(self._random.rand(len(lnpdiff))))
# /home/jovyan/ClimTrends/TrendGEVModel.py:42: UserWarning: This function actually returns the median instead of the mean, since the mean is not always defined for the GEV distribution.
#   warnings.warn("This function actually returns the median instead of the mean, since the mean is not always defined for the GEV distribution.")
